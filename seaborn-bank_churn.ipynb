# %%
#bank churn analytics
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load data
df=pd.read_csv(r"C:\Users\DELL\Desktop\workshop projects\datasets\data\Bank_churn_modelling.csv")
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# # data analytics pipeline

# %% [markdown]
# # 1.data collection-capturing data from differenct sources and creating a
# #     dataset
# # 2.data exploration-
# #    -understand data
# #   -understand business logic
# #    -identify faults/possible threats in data
# # 3.data cleaning
# # 4.exploratory analysis-explore data using statistics and visualization
# # 5.creating report

# %% [markdown]
# # Data exploration

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# RowNumber          10000 non-null int64
# CustomerId         10000 non-null int64
# Surname            10000 non-null object
# CreditScore        10000 non-null int64
# Geography          10000 non-null object
# Gender             10000 non-null object
# Age                10000 non-null int64
# Tenure             10000 non-null int64
# Balance            10000 non-null float64
# NumOfProducts      10000 non-null int64
# HasCrCard          10000 non-null int64
# IsActiveMember     10000 non-null int64
# EstimatedSalary    10000 non-null float64
# Exited             10000 non-null int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
#check for unique values in geography and gender
df.Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df.Geography.unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# # data cleaning

# %%
#check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
#check for missing values
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# # exploratory analysis
# # Bivariate analysis

# %%
#numeric v/s categorical
# credit v/s exited
plt.figure(figsize=(12,5))
sns.distplot(df.CreditScore[df.Exited==0])
sns.distplot(df.CreditScore[df.Exited==1])
plt.legend(['0','1'])
plt.show()

# %%
#numeric v/s categorical
# age v/s exited
plt.figure(figsize=(12,5))
sns.distplot(df.Age[df.Exited==0])
sns.distplot(df.Age[df.Exited==1])
plt.legend(['0','1'])
plt.show()

# %%
#the above graph shows that majority of customers leaving are from
#old age group, young age customers have less dropout rate

# %%
#categorical v/s categorical
#Geography v/s Exited
plt.figure(figsize=(6,3))
sns.countplot(df.Geography)
plt.show()
plt.figure(figsize=(6,3))
sns.countplot(df.Geography[df.Exited==1])
plt.show()

# %%
plt.figure(figsize=(6,3))
sns.countplot(df.Gender)
plt.show()
plt.figure(figsize=(6,3))
sns.countplot(df.Gender[df.Exited==1])
plt.show()

# %%
#categorical v/s categorical
#HasCrCard v/s Exited
plt.figure(figsize=(6,3))
sns.countplot(df.HasCrCard)
plt.show()
plt.figure(figsize=(6,3))
sns.countplot(df.HasCrCard[df.Exited==1])
plt.show()

# %%
#having a credit card or not doesn't affect the decreasing churn rate of bank

# %%
#multivariate analysis
#pointplot
#categorical v/s numeric v/s categorical
#x,y,hue>> x=categorical,y=numeric,hue=categorical
plt.figure(figsize=(12,5))
sns.pointplot(x='Geography',y='Age',hue='Exited',data=df)
plt.show()

# %%
#pointplot
#numeric v/s numeric v/s categorical
#creditscore v/s age v/s exited
#x,y,hue>> x=categorical,y=numeric,hue=categorical
plt.figure(figsize=(12,5))
sns.scatterplot(x='CreditScore',y='Age',hue='Exited',data=df)
plt.show()

# %% [markdown]
# Correlation
# -Always calculated between two attributes
# -Always gives clear information about about linear pattern between two attributes

# %%
#correlation range=[-1,+1]
#correlation analysis

# %%
cor=df.corr()
#heatmap for visualizing correaltion analysis
plt.figure(figsize=(10,8))
sns.heatmap(cor,annot=True,cmap='coolwarm')
plt.show()
